# %% [markdown]
# <a href="https://colab.research.google.com/github/Amiruzzaman-anan/Vehicle-Detection-from-Traffic/blob/main/Vehicle_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-30-g342fe05 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.0/78.2 GB disk)

# %% [markdown]
# # Data Extraction

# %%
# !unzip -q ../train_data -d../

# %%
# !zip -r '/content/yolov5/runs/detect/"exp2.zip"' '/content/yolov5/runs/detect/exp2/"1-30.zip"'
# Out:
# 	zip warning: name not matched: /content/yolov5/runs/detect/exp2/"1-30.zip"
#
# zip error: Nothing to do! (try: zip -r /content/yolov5/runs/detect/"exp2.zip" . -i /content/yolov5/runs/detect/exp2/"1-30.zip")

# %%
# !zip -r /content/yolov5/runs/detect/exp4.zip /content/yolov5/runs/detect/exp4
# Out:
# updating: content/yolov5/runs/detect/exp4/ (stored 0%)
# updating: content/yolov5/runs/detect/exp4/1-20.mp4 (deflated 1%)
# updating: content/yolov5/runs/detect/exp4/.ipynb_checkpoints/ (stored 0%)

# %% [markdown]
# # Detect Data

# %%
# !python detect.py --weights runs/train/exp8/weights/last.pt --img 640 --conf 0.35 --source /content/IMG_8206.MOV
# Out:
# detect: weights=['runs/train/exp8/weights/last.pt'], source=/content/IMG_8206.MOV, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-30-g342fe05 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/2500) /content/IMG_8206.MOV: 384x640 5 vehicles, 14.5ms
# video 1/1 (2/2500) /content/IMG_8206.MOV: 384x640 5 vehicles, 14.0ms
# video 1/1 (3/2500) /content/IMG_8206.MOV: 384x640 4 vehicles, 16.7ms
# video 1/1 (4/2500) /content/IMG_8206.MOV: 384x640 5 vehicles, 13.4ms
# ...

# %% [markdown]
# # Train Data

# %%
# !python train.py --img 640 --batch 20 --epochs 200 --data /content/yolov5/data/check.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data/check.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=20, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-30-g342fe05 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# Result

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
